# %%
# 1) Imports and plot styling
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import Pk_library as PKL

device = "cuda" if torch.cuda.is_available() else "cpu"
model_ckpt = '/home/sid/cosmo_compression/checkpoints/cosmoflow_seed_8_with_masking/step=step=12750-val_loss=val_loss=0.334.ckpt'   # ← change to your .ckpt
dataset_path = '/monolith/global_data/astro_compression/CAMELS/'

# %%
# 2) Device and model setup
from cosmo_compression.data import data
from cosmo_compression.model import represent

torch.manual_seed(42)
os.environ['CUDA_VISIBLE_DEVICES'] = '5'

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Map settings
MAP_TYPE = 'Mcdm'
MAP_RESOLUTION = 256
mean = data.NORM_DICT[MAP_TYPE][MAP_RESOLUTION]['mean']
std  = data.NORM_DICT[MAP_TYPE][MAP_RESOLUTION]['std']

# Load pretrained model
fm = represent.CosmoFlow.load_from_checkpoint(model_ckpt).to(device)
fm.eval()
# Out:
# CosmoFlow(
#   (encoder): ResNetEncoder(
#     (resnet_list): ModuleList(
#       (0): ResNet(
#         (in_layer): Sequential(
#           (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#         )
#         (resnet_layers): ModuleList(
#           (0-1): 2 x Sequential(
#             (0): ResnetBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (shortcut): Sequential()
#             )
#           )
#           (2): Sequential(
#             (0): ResnetBlock(
#               (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False, padding_mode=circular)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (shortcut): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False, padding_mode=circular)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (3): Sequential(
#             (0): ResnetBlock(
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False, padding_mode=circular)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (shortcut): Sequential(
#                 (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(2, 2), bias=False, padding_mode=circular)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (4): Sequential(
#             (0): ResnetBlock(
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (shortcut): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False, padding_mode=circular)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#           (5): Sequential(
#             (0): ResnetBlock(
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False, padding_mode=circular)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (shortcut): Sequential(
#                 (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(2, 2), bias=False, padding_mode=circular)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#           )
#         )
#         (out_conv): Conv2d(256, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#       )
#     )
#   )
#   (decoder): FlowMatching(
#     (velocity_model): UNet(
#       (dropout): Dropout2d(p=0.1, inplace=False)
#       (inc): UNetConv(
#         (conv1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#         (gn_1): AdaGN(
#           (gn): GroupNorm(8, 64, eps=1e-05, affine=True)
#         )
#         (gelu): GELU(approximate='none')
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#         (gn_2): AdaGN(
#           (gn): GroupNorm(8, 64, eps=1e-05, affine=True)
#         )
#         (t_scale_proj_1): Linear(in_features=256, out_features=64, bias=True)
#         (t_bias_proj_1): Linear(in_features=256, out_features=64, bias=True)
#         (t_scale_proj_2): Linear(in_features=256, out_features=64, bias=True)
#         (t_bias_proj_2): Linear(in_features=256, out_features=64, bias=True)
#         (z_scale_proj_1): Linear(in_features=126, out_features=64, bias=True)
#         (z_bias_proj_1): Linear(in_features=126, out_features=64, bias=True)
#         (z_scale_proj_2): Linear(in_features=126, out_features=64, bias=True)
#         (z_bias_proj_2): Linear(in_features=126, out_features=64, bias=True)
#       )
#       (down1): DownStep(
#         (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (conv1): UNetConv(
#           (conv1): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 72, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 72, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=72, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=72, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=72, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=72, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=72, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=72, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=72, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=72, bias=True)
#         )
#         (conv2): UNetConv(
#           (conv1): Conv2d(72, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 128, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 128, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=128, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=128, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=128, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=128, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=128, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=128, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=128, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=128, bias=True)
#         )
#         (gdn_layer): GDN()
#       )
#       (down2): DownStep(
#         (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (conv1): UNetConv(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 128, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 128, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=128, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=128, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=128, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=128, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=128, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=128, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=128, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=128, bias=True)
#         )
#         (conv2): UNetConv(
#           (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=256, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=256, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=256, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=256, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=256, bias=True)
#         )
#         (gdn_layer): GDN()
#       )
#       (sa2): SelfAttention(
#         (mha): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_self): Sequential(
#           (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (1): Linear(in_features=256, out_features=256, bias=True)
#           (2): GELU(approximate='none')
#           (3): Linear(in_features=256, out_features=256, bias=True)
#         )
#       )
#       (down3): DownStep(
#         (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (conv1): UNetConv(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=256, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=256, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=256, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=256, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=256, bias=True)
#         )
#         (conv2): UNetConv(
#           (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 512, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 512, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=512, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=512, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=512, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=512, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=512, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=512, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=512, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=512, bias=True)
#         )
#         (gdn_layer): GDN()
#       )
#       (sa3): SelfAttention(
#         (mha): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (ln): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (ff_self): Sequential(
#           (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (1): Linear(in_features=512, out_features=512, bias=True)
#           (2): GELU(approximate='none')
#           (3): Linear(in_features=512, out_features=512, bias=True)
#         )
#       )
#       (down4): DownStep(
#         (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (conv1): UNetConv(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 512, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 512, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=512, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=512, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=512, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=512, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=512, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=512, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=512, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=512, bias=True)
#         )
#         (conv2): UNetConv(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 512, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 512, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=512, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=512, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=512, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=512, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=512, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=512, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=512, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=512, bias=True)
#         )
#         (gdn_layer): GDN()
#       )
#       (up0): UpStep(
#         (conv1): UpsamplingUNetConv(
#           (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 512, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Sequential(
#             (0): Conv2d(512, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): PixelShuffle(upscale_factor=2)
#           )
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 512, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=512, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=512, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=512, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=512, bias=True)
#           (z_scale_proj_1): Linear(in_features=14, out_features=512, bias=True)
#           (z_bias_proj_1): Linear(in_features=14, out_features=512, bias=True)
#           (z_scale_proj_2): Linear(in_features=14, out_features=512, bias=True)
#           (z_bias_proj_2): Linear(in_features=14, out_features=512, bias=True)
#         )
#         (conv2): UNetConv(
#           (conv1): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 512, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=512, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=512, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=512, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=512, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=256, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=256, bias=True)
#         )
#         (gdn_layer): GDN()
#       )
#       (sa0_inv): SelfAttention(
#         (mha): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_self): Sequential(
#           (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (1): Linear(in_features=256, out_features=256, bias=True)
#           (2): GELU(approximate='none')
#           (3): Linear(in_features=256, out_features=256, bias=True)
#         )
#       )
#       (up1): UpStep(
#         (conv1): UpsamplingUNetConv(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): PixelShuffle(upscale_factor=2)
#           )
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=256, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (z_scale_proj_1): Linear(in_features=14, out_features=256, bias=True)
#           (z_bias_proj_1): Linear(in_features=14, out_features=256, bias=True)
#           (z_scale_proj_2): Linear(in_features=14, out_features=256, bias=True)
#           (z_bias_proj_2): Linear(in_features=14, out_features=256, bias=True)
#         )
#         (conv2): UNetConv(
#           (conv1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=256, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=256, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=256, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=256, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=256, bias=True)
#         )
#         (gdn_layer): GDN()
#       )
#       (sa1_inv): SelfAttention(
#         (mha): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#         )
#         (ln): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (ff_self): Sequential(
#           (0): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (1): Linear(in_features=256, out_features=256, bias=True)
#           (2): GELU(approximate='none')
#           (3): Linear(in_features=256, out_features=256, bias=True)
#         )
#       )
#       (up2): UpStep(
#         (conv1): UpsamplingUNetConv(
#           (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Sequential(
#             (0): Conv2d(256, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): PixelShuffle(upscale_factor=2)
#           )
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 256, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=256, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=256, bias=True)
#           (z_scale_proj_1): Linear(in_features=14, out_features=256, bias=True)
#           (z_bias_proj_1): Linear(in_features=14, out_features=256, bias=True)
#           (z_scale_proj_2): Linear(in_features=14, out_features=256, bias=True)
#           (z_bias_proj_2): Linear(in_features=14, out_features=256, bias=True)
#         )
#         (conv2): UNetConv(
#           (conv1): Conv2d(384, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 192, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(192, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 128, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=192, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=192, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=128, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=128, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=192, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=192, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=128, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=128, bias=True)
#         )
#         (gdn_layer): GDN()
#       )
#       (up3): UpStep(
#         (conv1): UpsamplingUNetConv(
#           (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (gn_1): AdaGN(
#             (gn): GroupNorm(8, 128, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Sequential(
#             (0): Conv2d(128, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (1): PixelShuffle(upscale_factor=2)
#           )
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 128, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=128, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=128, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=128, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=128, bias=True)
#           (z_scale_proj_1): Linear(in_features=14, out_features=128, bias=True)
#           (z_bias_proj_1): Linear(in_features=14, out_features=128, bias=True)
#           (z_scale_proj_2): Linear(in_features=14, out_features=128, bias=True)
#           (z_bias_proj_2): Linear(in_features=14, out_features=128, bias=True)
#         )
#         (conv2): UNetConv(
#           (conv1): Conv2d(200, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_1): AdaGN(
#             (gn): GroupNorm(4, 100, eps=1e-05, affine=True)
#           )
#           (gelu): GELU(approximate='none')
#           (conv2): Conv2d(100, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#           (gn_2): AdaGN(
#             (gn): GroupNorm(8, 64, eps=1e-05, affine=True)
#           )
#           (t_scale_proj_1): Linear(in_features=256, out_features=100, bias=True)
#           (t_bias_proj_1): Linear(in_features=256, out_features=100, bias=True)
#           (t_scale_proj_2): Linear(in_features=256, out_features=64, bias=True)
#           (t_bias_proj_2): Linear(in_features=256, out_features=64, bias=True)
#           (z_scale_proj_1): Linear(in_features=126, out_features=100, bias=True)
#           (z_bias_proj_1): Linear(in_features=126, out_features=100, bias=True)
#           (z_scale_proj_2): Linear(in_features=126, out_features=64, bias=True)
#           (z_bias_proj_2): Linear(in_features=126, out_features=64, bias=True)
#         )
#         (gdn_layer): GDN()
#       )
#       (outc): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#       (latent_upsampler_0): Sequential(
#         (0): UpStepWoutRes(
#           (conv1): UNetConv(
#             (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#             (gn_1): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (gelu): GELU(approximate='none')
#             (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#             (gn_2): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (t_scale_proj_1): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_1): Linear(in_features=256, out_features=8, bias=True)
#             (t_scale_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (z_scale_proj_1): Linear(in_features=126, out_features=8, bias=True)
#             (z_bias_proj_1): Linear(in_features=126, out_features=8, bias=True)
#             (z_scale_proj_2): Linear(in_features=126, out_features=8, bias=True)
#             (z_bias_proj_2): Linear(in_features=126, out_features=8, bias=True)
#           )
#           (conv2): UpsamplingUNetConv(
#             (conv1): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (gn_1): AdaGN(
#               (gn): GroupNorm(4, 4, eps=1e-05, affine=True)
#             )
#             (gelu): GELU(approximate='none')
#             (conv2): Sequential(
#               (0): Conv2d(4, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): PixelShuffle(upscale_factor=2)
#             )
#             (gn_2): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (t_scale_proj_1): Linear(in_features=256, out_features=4, bias=True)
#             (t_bias_proj_1): Linear(in_features=256, out_features=4, bias=True)
#             (t_scale_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (z_scale_proj_1): Linear(in_features=14, out_features=4, bias=True)
#             (z_bias_proj_1): Linear(in_features=14, out_features=4, bias=True)
#             (z_scale_proj_2): Linear(in_features=14, out_features=8, bias=True)
#             (z_bias_proj_2): Linear(in_features=14, out_features=8, bias=True)
#           )
#         )
#         (1): UpStepWoutRes(
#           (conv1): UNetConv(
#             (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#             (gn_1): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (gelu): GELU(approximate='none')
#             (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#             (gn_2): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (t_scale_proj_1): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_1): Linear(in_features=256, out_features=8, bias=True)
#             (t_scale_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (z_scale_proj_1): Linear(in_features=126, out_features=8, bias=True)
#             (z_bias_proj_1): Linear(in_features=126, out_features=8, bias=True)
#             (z_scale_proj_2): Linear(in_features=126, out_features=8, bias=True)
#             (z_bias_proj_2): Linear(in_features=126, out_features=8, bias=True)
#           )
#           (conv2): UpsamplingUNetConv(
#             (conv1): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (gn_1): AdaGN(
#               (gn): GroupNorm(4, 4, eps=1e-05, affine=True)
#             )
#             (gelu): GELU(approximate='none')
#             (conv2): Sequential(
#               (0): Conv2d(4, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): PixelShuffle(upscale_factor=2)
#             )
#             (gn_2): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (t_scale_proj_1): Linear(in_features=256, out_features=4, bias=True)
#             (t_bias_proj_1): Linear(in_features=256, out_features=4, bias=True)
#             (t_scale_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (z_scale_proj_1): Linear(in_features=14, out_features=4, bias=True)
#             (z_bias_proj_1): Linear(in_features=14, out_features=4, bias=True)
#             (z_scale_proj_2): Linear(in_features=14, out_features=8, bias=True)
#             (z_bias_proj_2): Linear(in_features=14, out_features=8, bias=True)
#           )
#         )
#         (2): UpStepWoutRes(
#           (conv1): UNetConv(
#             (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#             (gn_1): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (gelu): GELU(approximate='none')
#             (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#             (gn_2): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (t_scale_proj_1): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_1): Linear(in_features=256, out_features=8, bias=True)
#             (t_scale_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (z_scale_proj_1): Linear(in_features=126, out_features=8, bias=True)
#             (z_bias_proj_1): Linear(in_features=126, out_features=8, bias=True)
#             (z_scale_proj_2): Linear(in_features=126, out_features=8, bias=True)
#             (z_bias_proj_2): Linear(in_features=126, out_features=8, bias=True)
#           )
#           (conv2): UpsamplingUNetConv(
#             (conv1): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (gn_1): AdaGN(
#               (gn): GroupNorm(4, 4, eps=1e-05, affine=True)
#             )
#             (gelu): GELU(approximate='none')
#             (conv2): Sequential(
#               (0): Conv2d(4, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): PixelShuffle(upscale_factor=2)
#             )
#             (gn_2): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (t_scale_proj_1): Linear(in_features=256, out_features=4, bias=True)
#             (t_bias_proj_1): Linear(in_features=256, out_features=4, bias=True)
#             (t_scale_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (z_scale_proj_1): Linear(in_features=14, out_features=4, bias=True)
#             (z_bias_proj_1): Linear(in_features=14, out_features=4, bias=True)
#             (z_scale_proj_2): Linear(in_features=14, out_features=8, bias=True)
#             (z_bias_proj_2): Linear(in_features=14, out_features=8, bias=True)
#           )
#         )
#         (3): UpStepWoutRes(
#           (conv1): UNetConv(
#             (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#             (gn_1): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (gelu): GELU(approximate='none')
#             (conv2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, padding_mode=circular)
#             (gn_2): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (t_scale_proj_1): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_1): Linear(in_features=256, out_features=8, bias=True)
#             (t_scale_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (z_scale_proj_1): Linear(in_features=126, out_features=8, bias=True)
#             (z_bias_proj_1): Linear(in_features=126, out_features=8, bias=True)
#             (z_scale_proj_2): Linear(in_features=126, out_features=8, bias=True)
#             (z_bias_proj_2): Linear(in_features=126, out_features=8, bias=True)
#           )
#           (conv2): UpsamplingUNetConv(
#             (conv1): Conv2d(8, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (gn_1): AdaGN(
#               (gn): GroupNorm(4, 4, eps=1e-05, affine=True)
#             )
#             (gelu): GELU(approximate='none')
#             (conv2): Sequential(
#               (0): Conv2d(4, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (1): PixelShuffle(upscale_factor=2)
#             )
#             (gn_2): AdaGN(
#               (gn): GroupNorm(8, 8, eps=1e-05, affine=True)
#             )
#             (t_scale_proj_1): Linear(in_features=256, out_features=4, bias=True)
#             (t_bias_proj_1): Linear(in_features=256, out_features=4, bias=True)
#             (t_scale_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (t_bias_proj_2): Linear(in_features=256, out_features=8, bias=True)
#             (z_scale_proj_1): Linear(in_features=14, out_features=4, bias=True)
#             (z_bias_proj_1): Linear(in_features=14, out_features=4, bias=True)
#             (z_scale_proj_2): Linear(in_features=14, out_features=8, bias=True)
#             (z_bias_proj_2): Linear(in_features=14, out_features=8, bias=True)
#           )
#         )
#       )
#       (pool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Linear(in_features=8, out_features=126, bias=True)
#     )
#   )
# )

# %%
# 3) Load dataset and select samples
dataset = data.CAMELS(
    root=dataset_path,
    map_type=MAP_TYPE,
    dataset='1P',
    parameters=['Omega_m','sigma_8','A_SN1','A_SN2','A_AGN1','A_AGN2','Omega_b'],
)

# original and target
img0, _ = dataset[1]
img1, _ = dataset[61]
# bring to device
img0 = torch.tensor(img0).unsqueeze(0).to(device)
img1 = torch.tensor(img1).unsqueeze(0).to(device)

# %%
# 4) Encode and compute input P(k)
# Encode
h0 = fm.encoder(img0)
h1 = fm.encoder(img1)

# Un-normalize for plotting
img0_np = img0.cpu().numpy()[0,0] * std + mean
img1_np = img1.cpu().numpy()[0,0] * std + mean

# Compute P(k)
delta0 = img0_np/np.mean(img0_np) - 1
delta1 = img1_np/np.mean(img1_np) - 1
pk0 = PKL.Pk_plane(delta0, 25.0, 'None', 1, verbose=False)
pk1 = PKL.Pk_plane(delta1, 25.0, 'None', 1, verbose=False)
k0, Pk0 = pk0.k, pk0.Pk
k1, Pk1 = pk1.k, pk1.Pk

# %%
# 5) Modulation-stage latent swaps
# Channels to interpolate in the example are detenmined for the 8-channel model.

modulation_ranges = {
    'High Frequency': list(range(0,2)),
    'Low Frequency':  list(range(2,8)),
}

n_samples = 40
x0 = torch.randn((1,1,MAP_RESOLUTION,MAP_RESOLUTION), device=device)

intermediate = []
for label, chans in modulation_ranges.items():
    h_mod = h0.clone()
    h_mod[:,chans,:,:] = h1[:,chans,:,:]
    with torch.no_grad():
        decoded = fm.decoder.predict(x0, h=h_mod, n_sampling_steps=n_samples)
    img_mod = decoded.cpu().numpy()[0,0]*std + mean
    pk2 = PKL.Pk_plane(img_mod/np.mean(img_mod)-1, 25.0, 'None', 1, verbose=False)
    intermediate.append((label, img_mod, pk2.k, pk2.Pk))

# %%
# 6) Plot multi-column grid
n_int = len(intermediate)
n_cols = n_int + 2
fig, axs = plt.subplots(2, n_cols, figsize=(4*n_cols, 8))

colors = {'orig':'C0','recon':'C1','targ':'C2'}
lw = 1.5
labels = ['(a)','(b)','(c)','(d)']

# Original
axs[0,0].imshow(img0_np, cmap='viridis', origin='lower')
axs[0,0].set_title('Source CDM Field'); axs[0,0].axis('off')
ax0pk = axs[1,0]
ax0pk.plot(k0, Pk0, '--', color=colors['orig'], lw=lw)
ax0pk.plot(k1, Pk1, '--', color=colors['targ'], lw=lw)
ax0pk.set(xscale='log', yscale='log', xlabel='$k$ [h/Mpc]', ylabel='$P(k)$ [h/Mpc]^2', ylim=(5e-8,1e-1))
ax0pk.text(0.47,-0.3,labels[0], transform=axs[1,0].transAxes, fontsize=20, fontweight='bold')

# Intermediates
for i,(lab, img_mod, k_mod, Pk_mod) in enumerate(intermediate):
    c = i+1
    axs[0,c].imshow(img_mod, cmap='viridis', origin='lower')
    axs[0,c].set_title(lab); axs[0,c].axis('off')
    axpk = axs[1,c]
    axpk.plot(k_mod, Pk_mod, color=colors['recon'], lw=lw)
    axpk.plot(k0, Pk0, '--', color=colors['orig'], lw=lw)
    axpk.plot(k1, Pk1, '--', color=colors['targ'], lw=lw)
    axpk.set(xscale='log', yscale='log', xlabel='$k$ [h/Mpc]', ylabel='$P(k)$ [h/Mpc]^2', ylim=(5e-8,1e-1))
    axpk.text(0.47,-0.3,labels[c], transform=axs[1,c].transAxes, fontsize=20, fontweight='bold')
    axpk.legend()

# Final
fcol = n_cols-1
axs[0,fcol].imshow(img1_np, cmap='viridis', origin='lower')
axs[0,fcol].set_title('Target CDM Field'); axs[0,fcol].axis('off')
axfpk = axs[1,fcol]
axfpk.plot(k0, Pk0, '--', color=colors['orig'], lw=lw)
axfpk.plot(k1, Pk1, '--', color=colors['targ'], lw=lw)
axfpk.set(xscale='log', yscale='log', xlabel='$k$ [h/Mpc]', ylabel='$P(k)$ [h/Mpc]^2', ylim=(5e-8,1e-1))
axfpk.text(0.47,-0.3,labels[fcol], transform=axs[1,fcol].transAxes, fontsize=20, fontweight='bold')
axfpk.legend()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3841759/2330259023.py:30: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axpk.legend()
# /tmp/ipykernel_3841759/2330259023.py:41: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axfpk.legend()
